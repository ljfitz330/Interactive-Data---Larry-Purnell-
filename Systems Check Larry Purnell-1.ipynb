# %% [markdown]
# # Systems Check
# ### Larry Purnell
# ##### Emat 62110
#
# Making a list
#
# - thing one
#  1. thing two
#
# __Bold__
#
# __Italic__
#
# ![image](https://www.denofgeek.com/wp-content/uploads/2022/05/Leged-of-Zelda-Link.jpg?resize=768%2C432)
#
# I hope to learn more about the fundamentals of Python for digital visualizations. Expanding my knowledge in different coding languages.
#
# Thank you,

# %%
my_name = "Larry"
my_name 

def give_name():
    print(my_name)

give_name()

def return_name():
    return my_name
# Out:
# Larry
